# %%
# This notebook was created to do validation on collaboration filtering models
# It relies on a data extract in certain formats to operate, although there is a mock data generator
#
# There are 2 main functions:
#
# ** collab_recall_validation_tester()
# Input: customer purchase data, testing prarameters
# K-fold will be used for validation, using the (k-1)/k of the customer purcahse data to build a co-occurrence
# matrix and validating with 1/k of the data. The 1/k of the data will have X number of purchases removed
# for each customer and try to recommend the missing purchase using the co-occurrence matrix. The limitation
# is that any users with less than X purchases will not be used to calculate the accurracy.
# Output: Recall Accurracy
# **
#
# ** collab_catalog_validation_tester()
# Input: customer purchase data, testing prarameters
# K-fold will be used for validation, using the (k-1)/k of the customer purcahse data to build a co-occurrence
# matrix and validating with 1/k of the data. The 1/k of the data will keep all the original customer purchases
# and use it to recommend products using the co-occurrence matrix. Taking all the recommended products and 
# dividing it by the total amount of products offered will give us catalog coverage.
# Output: Catalog Coverage
# **
#
# Testing with categories is not implemented yet

# %%
import numpy as np
import random
import time
from sklearn.model_selection import KFold
import json
import sys
from datetime import date, datetime
import pandas as pd

# %%
# Create co-occurrence matrix

def create_cocmatrix(subset_matrix_cust_order):
    rows, cols = subset_matrix_cust_order.shape
    m = np.zeros((cols,cols))
    
    for i in range(cols):
        t = np.sum(subset_matrix_cust_order[subset_matrix_cust_order[:,i] > 0],axis=0)
        t[i] = 0
        m[i,:] = t
        
        #if i % (cols/5) == 0:
        #    print "created rows in cooccurrence matrix at row",i
            
    return m

# %%
def create_seed(rand):
    np.random.seed(rand) # create seed for repeatable results

# %%
# initialize all data for collaborative
# customer to demographic lookup
arr_cxd = np.load('demo_matrix.npy')

print "created customer to demographic lookup"

# customer to order lookup
matrix_co = np.load('cust_item_matrix.npy')

print "created customer to order lookup"

regions = []

with open("regions.txt", 'r') as regioninputs:
    for r in regioninputs:
        r = r.strip()
        try:
            rname, rid = r.split('\t')
        except:
            continue
            
        regions.append(float(rid))
        
regions = list(set(regions))
# Out:
# created customer to demographic lookup
# created customer to order lookup

# %%
# print statistics
print "\ncustomer x demographic shape:",arr_cxd.shape
print "customer regions + unknown:",len(np.unique(arr_cxd[:,0]))

for num, name in enumerate(np.unique(arr_cxd[:,0])):
    print "\tregion",name,"% of pop",len(np.where(arr_cxd[:,0] == name)[0])/float(arr_cxd.shape[0])*100
    
print "customer genders + unknown:",len(np.unique(arr_cxd[:,1]))

for num, name in enumerate(np.unique(arr_cxd[:,1])):
    print "\tgender",name,"% of pop",len(np.where(arr_cxd[:,1] == name)[0])/float(arr_cxd.shape[0])*100
    
print "\ncustomer x purchases shape:",matrix_co.shape # customer and purchases
print "if already normalized the stats should be the same"
print "not normalized"

stat_sum_not_normal = np.sum(matrix_co,axis=1)

print "customer average purchases (multiples of item allowed):",np.mean(stat_sum_not_normal)
print "customer variance purchases (multiples of item allowed):",np.var(stat_sum_not_normal)
print "customer min purchases (multiples of item allowed):",np.min(stat_sum_not_normal)
print "customer max purchases (multiples of item allowed):",np.max(stat_sum_not_normal)
print "normalized"

stat_sum_normal = np.count_nonzero(matrix_co,axis=1)

print "customer average purchases (multiples of item set to 1):",np.mean(stat_sum_normal)
print "customer variance purchases (multiples of item set to 1):",np.var(stat_sum_normal)
print "customer min purchases (multiples of item set to 1):",np.min(stat_sum_normal)
print "customer max purchases (multiples of item set to 1):",np.max(stat_sum_normal)
print "customers that bought at least 1 item:",len(np.where(np.sum(matrix_co,axis=1) > 0)[0])
print "customers that bought at least 2 item:",len(np.where(np.sum(matrix_co,axis=1) > 1)[0])
print "customers that bought at least 3 item:",len(np.where(np.sum(matrix_co,axis=1) > 2)[0])
print "customers that bought at least 4 item:",len(np.where(np.sum(matrix_co,axis=1) > 3)[0])
print "customers that bought at least 5 item:",len(np.where(np.sum(matrix_co,axis=1) > 4)[0])
# Out:
# customer x demographic shape: (189559, 2)
# customer regions + unknown: 22
# 	region 0.0 % of pop 0.193079727156
# 	region 1.0 % of pop 10.3403162076
# 	region 2.0 % of pop 42.9655146946
# 	region 3.0 % of pop 8.69280804393
# 	region 4.0 % of pop 2.49262762517
# 	region 5.0 % of pop 14.3607003624
# 	region 6.0 % of pop 1.45653859748
# 	region 7.0 % of pop 4.01194351099
# 	region 8.0 % of pop 3.41318534071
# 	region 9.0 % of pop 11.9308500256
# 	region 10.0 % of pop 0.0949572428637
# 	region 11.0 % of pop 0.00474786214318
# 	region 12.0 % of pop 0.0290147130972
# 	region 13.0 % of pop 0.00896818404824
# 	region 15.0 % of pop 0.000527540238132
# 	region 18.0 % of pop 0.00105508047626
# 	region 20.0 % of pop 0.000527540238132
# 	region 21.0 % of pop 0.000527540238132
# 	region 22.0 % of pop 0.000527540238132
# 	region 28.0 % of pop 0.000527540238132
# 	region 30.0 % of pop 0.000527540238132
# 	region 35.0 % of pop 0.000527540238132
# customer genders + unknown: 3
# 	gender 0.0 % of pop 8.54826201869
# 	gender 1.0 % of pop 50.8976097152
# 	gender 2.0 % of pop 40.5541282661
#
# customer x purchases shape: (189559, 3990)
# if already normalized the stats should be the same
# not normalized
# customer average purchases (multiples of item allowed): 1.44386180556
# customer variance purchases (multiples of item allowed): 1.28894093873
# customer min purchases (multiples of item allowed): 1.0
# customer max purchases (multiples of item allowed): 150.0
# normalized
# customer average purchases (multiples of item set to 1): 1.44386180556
# customer variance purchases (multiples of item set to 1): 1.28894093873
# customer min purchases (multiples of item set to 1): 1
# customer max purchases (multiples of item set to 1): 150
# customers that bought at least 1 item: 189559
# customers that bought at least 2 item: 51204
# customers that bought at least 3 item: 18685
# customers that bought at least 4 item: 6562
# customers that bought at least 5 item: 3069

# %%
# generate recommendations
# purchase_vec = customer purchases (vector)
# cocm = co occurrence matrix [items x items]
# num_rec = number of recommendations
def gen_recom(purchase_list,cocm,num_rec):
    rowsum = np.zeros(cocm.shape[0])
    
    for p in purchase_list:
        rowsum += cocm[p,:]
        
    rowsum[purchase_list] = 0
    indices = np.nonzero(rowsum)[0]
    toprec = indices[np.argsort(rowsum[indices])][-1 * num_rec:][::-1]
    return toprec

# %%
def get_indices(dataset, col, var=None):
    if var is None:
        return [y for y, x in enumerate(dataset[:,col])] # all
    
    return [y for y, x in enumerate(dataset[:,col]) if x == var]

# %%
def check_idx_size(idxlist,maximum_rows):
    if len(idxlist) > maximum_rows:
        return np.random.choice(idxlist, maximum_rows, replace=False)
    
    return idxlist

# %%
#80/20, 80 for 10-fold cross validation, 20 for test set holdout
create_seed(0)
indices = np.random.permutation(matrix_co.shape[0])
tsize = int(matrix_co.shape[0]*.8)

# customer to order matrix
matrix_co_training_idx, matrix_co_testing_idx  = indices[:tsize], indices[tsize:]
matrix_co_training, matrix_co_testing = matrix_co[matrix_co_training_idx,:], matrix_co[matrix_co_testing_idx,:]

# demo matrix
arr_cxd_training_idx, arr_cxd_testing_idx = indices[:tsize], indices[tsize:]
arr_cxd_training, arr_cxd_testing = arr_cxd[arr_cxd_training_idx,:], arr_cxd[arr_cxd_testing_idx,:]

# %%
matrix_co_training.shape, arr_cxd_training.shape, matrix_co.shape, arr_cxd.shape
# Out:
# ((151647, 3990), (151647, 2), (189559, 3990), (189559, 2))

# %%
# put matrixes in to get cross validation recall
# generate recommendations
# mco = matrix of customer to order [customer x items]
# num_rec = number of recommendations
# num_folds = k number of folds for cross validation
# recall_remove = removed number from purchase history
def collab_recall_validation_tester(mco,num_rec,num_folds,recall_remove):
    # cross validation n-folds
    start_time = time.time()
    kf = KFold(n_splits=num_folds)
    list_total_acc=[]
    k_index = 0
    
    for train, test in kf.split(mco):
        print "------------------------------------start new k=",k_index,\
        ",train set=",mco[train].shape[0],\
        ",validation set=",mco[test].shape[0]
        list_sub_acc = []
        # build co-occurrence matrix
        coo_matrix = create_cocmatrix(mco[train])

        # loop through test set
        # for each customer in test pool
        for i in range(mco[test].shape[0]):
            
            #print "customer",i
            # purchase vector
            #print "purchase vector"
            p_vec = mco[test][i,:]
            #print p_vec
            # determine purchase indexes
            #print "purchase indexes"
            list_original_purchases = np.where(p_vec > 0)[0]
            #print list_original_purchases
            
            # only run tests on customers with > recall_remove purchases for prediction
            if len(list_original_purchases) > recall_remove:
                # randomly select indexes to leave out
                #print "remove purchase indexes"
                #list_removed_purchases = np.random.choice(list_original_purchases,size=recall_remove, replace=False)
                list_removed_purchases = random.sample(list_original_purchases,recall_remove)
                #print list_removed_purchases
                # remove
                list_modified_purchases = list(set(list_original_purchases) - set(list_removed_purchases))
                #print "modified purchase vector"
                #p_vec_mod = np.zeros(p_vec.shape[0])
                #p_vec_mod[list_modified_purchases] = 1
                #print p_vec_mod
                # get sum all purchases except ones left out
                list_summed_coo_vec = gen_recom(list_modified_purchases,coo_matrix,num_rec)
                #print list_summed_coo_vec
                # check if return recommendations are in list
                list_recommended_match = set(list_removed_purchases) & set(list_summed_coo_vec)
                acc = len(list_recommended_match)/float(len(list_removed_purchases))
                #print "predicted ratio",accuracy
                list_sub_acc.append(acc)
                #print "end customer",i

                #if i % 500 == 0:
                # sanity check to make sure not all recommendations are #1
                #if (list_removed_purchases[0] != list_summed_coo_vec[0]) & (acc == 1):
                #    print "\t--customer example index",i
                #    print "\toriginal purchased indexes",list_original_purchases
                #    print "\tremoved index",list_removed_purchases
                #    print "\toriginal modified purchase indexes",np.where(p_vec_mod > 0)[0]
                #    print "\tpredicted indexes",list_summed_coo_vec     
                #    print "\tpredicted accuracy ratio",acc
                #    print "\t--customer end example index",i
            #else:
                #print "skipped due to length of purchases",list_original_purchases,\
                #"less than recall remove",recall_remove
        mean_sub_acc = np.mean(list_sub_acc)
        print "** number of elements in calculation",len(list_sub_acc)
        #print list_sub_acc
        print "** average fold accuracy",mean_sub_acc
        list_total_acc.append(mean_sub_acc)
        k_index += 1
        print "**time elapsed",(time.time() - start_time)
        print "------------------------------------end"
    print "list of total accuracy for each fold",list_total_acc
    average = np.mean(list_total_acc)
    print num_folds,"-fold total average",average
    print "time elapsed",(time.time() - start_time)
    return average

def demo_filter(mco,mdo,regions,maximum_rows,minimum_rows,num_rec,num_folds,recall_remove):
    list_info = []
    
    for r in regions:
        if r == 0.0:
            ridx = get_indices(mdo, 0) # use all regions
        else:   
            ridx = get_indices(mdo, 0, r) # look for region r in col 0

            if len(ridx) == 0:
                print "region: {0} not found".format(r)
                continue

        for g in [1.0,2.0,0.0]: #gender_list:
            if g == 0.0:
                gidx = get_indices(mdo, 1) # all, col 1 is gender
            else:
                gidx = get_indices(mdo, 1, g)

                if len(gidx) == 0:
                    print "gender: {0} not found".format(g)
                    continue

            interidx = list(set(ridx).intersection(set(gidx)))

            if len(interidx) < minimum_rows:
                print "too little data with region {0} and gender {1} found".format(r, g)
                continue

            interidx = check_idx_size(interidx,maximum_rows) # limit size
            print "\nregion: {0}, gender: {1}, intersect: {2}, {3}".format(r, g, len(interidx), len(mco))
                             
            total_accuracy = collab_recall_validation_tester(mco[interidx],num_rec,num_folds,recall_remove)
            list_info.append((r,g,mco[interidx].shape[0],total_accuracy))
    
    return list_info

# %%
# General test
seed = 0
create_seed(seed)
maximum_rows = 25000
minimum_rows = 1000

# test set
#randidx = np.random.choice(matrix_co_training.shape[0], 10000, replace=False)
#demo_results = demo_filter(matrix_co_training[randidx],arr_cxd_training[randidx],\
#                           regions,maximum_rows,minimum_rows,10,10,1)

# big set
demo_results = demo_filter(matrix_co_training,arr_cxd_training,\
                           regions,maximum_rows,minimum_rows,10,10,1)
# Out:
# region: 0.0, gender: 1.0, intersect: 25000, 151647
# ------------------------------------start new k= 0 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 657
# ** average fold accuracy 0.630136986301
# **time elapsed 99.2167019844
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 689
# ** average fold accuracy 0.641509433962
# **time elapsed 188.74141407
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 683
# ** average fold accuracy 0.647144948755
# **time elapsed 279.318017006
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 695
# ** average fold accuracy 0.631654676259
# **time elapsed 368.374351025
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 680
# ** average fold accuracy 0.577941176471
# **time elapsed 456.968781948
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 672
# ** average fold accuracy 0.633928571429
# **time elapsed 546.713855028
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 667
# ** average fold accuracy 0.628185907046
# **time elapsed 635.648388863
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 696
# ** average fold accuracy 0.656609195402
# **time elapsed 726.632741928
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 671
# ** average fold accuracy 0.615499254844
# **time elapsed 815.817648888
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 724
# ** average fold accuracy 0.639502762431
# **time elapsed 905.273087025
# ------------------------------------end
# list of total accuracy for each fold [0.63013698630136983, 0.64150943396226412, 0.64714494875549045, 0.63165467625899285, 0.57794117647058818, 0.6339285714285714, 0.62818590704647681, 0.6566091954022989, 0.61549925484351709, 0.63950276243093918]
# 10 -fold total average 0.63021129129
# time elapsed 905.274555922
#
# region: 0.0, gender: 2.0, intersect: 25000, 151647
# ------------------------------------start new k= 0 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 641
# ** average fold accuracy 0.602184087363
# **time elapsed 90.3786859512
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 634
# ** average fold accuracy 0.580441640379
# **time elapsed 179.367639065
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 656
# ** average fold accuracy 0.606707317073
# **time elapsed 274.812775135
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 708
# ** average fold accuracy 0.579096045198
# **time elapsed 368.65308094
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 630
# ** average fold accuracy 0.593650793651
# **time elapsed 462.653344154
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 692
# ** average fold accuracy 0.606936416185
# **time elapsed 556.228139162
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 652
# ** average fold accuracy 0.581288343558
# **time elapsed 649.448358059
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 673
# ** average fold accuracy 0.583952451709
# **time elapsed 744.64872694
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 656
# ** average fold accuracy 0.579268292683
# **time elapsed 838.007337093
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 637
# ** average fold accuracy 0.579277864992
# **time elapsed 932.44759202
# ------------------------------------end
# list of total accuracy for each fold [0.60218408736349449, 0.58044164037854895, 0.60670731707317072, 0.57909604519774016, 0.59365079365079365, 0.60693641618497107, 0.58128834355828218, 0.58395245170876675, 0.57926829268292679, 0.57927786499215073]
# 10 -fold total average 0.589280325279
# time elapsed 932.448385954
#
# region: 0.0, gender: 0.0, intersect: 25000, 151647
# ------------------------------------start new k= 0 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 648
# ** average fold accuracy 0.58487654321
# **time elapsed 89.1202549934
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 696
# ** average fold accuracy 0.609195402299
# **time elapsed 182.886855125
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 714
# ** average fold accuracy 0.614845938375
# **time elapsed 277.538172007
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 662
# ** average fold accuracy 0.608761329305
# **time elapsed 371.053330898
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 682
# ** average fold accuracy 0.626099706745
# **time elapsed 465.101818085
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 667
# ** average fold accuracy 0.622188905547
# **time elapsed 558.984911919
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 659
# ** average fold accuracy 0.602427921093
# **time elapsed 652.729784966
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 712
# ** average fold accuracy 0.634831460674
# **time elapsed 748.518050909
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 675
# ** average fold accuracy 0.586666666667
# **time elapsed 842.04467392
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 668
# ** average fold accuracy 0.63622754491
# **time elapsed 936.667943954
# ------------------------------------end
# list of total accuracy for each fold [0.58487654320987659, 0.60919540229885061, 0.61484593837535018, 0.60876132930513593, 0.62609970674486803, 0.62218890554722639, 0.60242792109256449, 0.6348314606741573, 0.58666666666666667, 0.63622754491017963]
# 10 -fold total average 0.612612141882
# time elapsed 936.675398111
# region: 1.0, gender: 1.0, intersect: 7924, 151647
# ------------------------------------start new k= 0 ,train set= 7131 ,validation set= 793
# ** number of elements in calculation 206
# ** average fold accuracy 0.577669902913
# **time elapsed 9.98088812828
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 7131 ,validation set= 793
# ** number of elements in calculation 233
# ** average fold accuracy 0.570815450644
# **time elapsed 20.060762167
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 7131 ,validation set= 793
# ** number of elements in calculation 224
# ** average fold accuracy 0.59375
# **time elapsed 29.8755362034
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 7131 ,validation set= 793
# ** number of elements in calculation 236
# ** average fold accuracy 0.601694915254
# **time elapsed 39.4674110413
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 7132 ,validation set= 792
# ** number of elements in calculation 224
# ** average fold accuracy 0.589285714286
# **time elapsed 49.2635350227
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 7132 ,validation set= 792
# ** number of elements in calculation 207
# ** average fold accuracy 0.642512077295
# **time elapsed 59.1090760231
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 7132 ,validation set= 792
# ** number of elements in calculation 203
# ** average fold accuracy 0.625615763547
# **time elapsed 68.9876570702
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 7132 ,validation set= 792
# ** number of elements in calculation 207
# ** average fold accuracy 0.6038647343
# **time elapsed 78.7366271019
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 7132 ,validation set= 792
# ** number of elements in calculation 234
# ** average fold accuracy 0.529914529915
# **time elapsed 88.5409221649
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 7132 ,validation set= 792
# ** number of elements in calculation 203
# ** average fold accuracy 0.527093596059
# **time elapsed 98.4549570084
# ------------------------------------end
# list of total accuracy for each fold [0.57766990291262132, 0.57081545064377681, 0.59375, 0.60169491525423724, 0.5892857142857143, 0.64251207729468596, 0.62561576354679804, 0.60386473429951693, 0.52991452991452992, 0.52709359605911332]
# 10 -fold total average 0.586221668421
# time elapsed 98.4556090832
#
# region: 1.0, gender: 2.0, intersect: 6579, 151647
# ------------------------------------start new k= 0 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 176
# ** average fold accuracy 0.585227272727
# **time elapsed 7.35656094551
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 189
# ** average fold accuracy 0.539682539683
# **time elapsed 14.7626559734
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 212
# ** average fold accuracy 0.528301886792
# **time elapsed 22.1365680695
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 180
# ** average fold accuracy 0.527777777778
# **time elapsed 29.2252509594
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 176
# ** average fold accuracy 0.528409090909
# **time elapsed 36.4822509289
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 164
# ** average fold accuracy 0.518292682927
# **time elapsed 43.904886961
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 181
# ** average fold accuracy 0.580110497238
# **time elapsed 51.1450920105
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 182
# ** average fold accuracy 0.565934065934
# **time elapsed 58.3636569977
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 5921 ,validation set= 658
# ** number of elements in calculation 171
# ** average fold accuracy 0.444444444444
# **time elapsed 65.699712038
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 5922 ,validation set= 657
# ** number of elements in calculation 195
# ** average fold accuracy 0.502564102564
# **time elapsed 72.9335129261
# ------------------------------------end
# list of total accuracy for each fold [0.58522727272727271, 0.53968253968253965, 0.52830188679245282, 0.52777777777777779, 0.52840909090909094, 0.51829268292682928, 0.58011049723756902, 0.56593406593406592, 0.44444444444444442, 0.50256410256410255]
# 10 -fold total average 0.5320744361
# time elapsed 72.9342730045
#
# region: 1.0, gender: 0.0, intersect: 15758, 151647
# ------------------------------------start new k= 0 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 410
# ** average fold accuracy 0.617073170732
# **time elapsed 36.0408740044
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 445
# ** average fold accuracy 0.555056179775
# **time elapsed 72.0326151848
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 450
# ** average fold accuracy 0.575555555556
# **time elapsed 107.894748211
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 451
# ** average fold accuracy 0.592017738359
# **time elapsed 143.290739059
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 441
# ** average fold accuracy 0.603174603175
# **time elapsed 180.042415142
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 424
# ** average fold accuracy 0.629716981132
# **time elapsed 215.709081173
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 421
# ** average fold accuracy 0.600950118765
# **time elapsed 251.415116072
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 14182 ,validation set= 1576
# ** number of elements in calculation 414
# ** average fold accuracy 0.574879227053
# **time elapsed 287.456502199
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 14183 ,validation set= 1575
# ** number of elements in calculation 443
# ** average fold accuracy 0.575620767494
# **time elapsed 323.424566031
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 14183 ,validation set= 1575
# ** number of elements in calculation 425
# ** average fold accuracy 0.552941176471
# **time elapsed 359.308637142
# ------------------------------------end
# list of total accuracy for each fold [0.61707317073170731, 0.55505617977528088, 0.5755555555555556, 0.5920177383592018, 0.60317460317460314, 0.62971698113207553, 0.60095011876484561, 0.5748792270531401, 0.57562076749435664, 0.55294117647058827]
# 10 -fold total average 0.587698551851
# time elapsed 359.309469223
# region: 2.0, gender: 1.0, intersect: 25000, 151647
# ------------------------------------start new k= 0 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 650
# ** average fold accuracy 0.667692307692
# **time elapsed 89.9008989334
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 691
# ** average fold accuracy 0.671490593343
# **time elapsed 179.173871994
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 698
# ** average fold accuracy 0.63323782235
# **time elapsed 274.113818884
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 648
# ** average fold accuracy 0.645061728395
# **time elapsed 367.919239998
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 636
# ** average fold accuracy 0.647798742138
# **time elapsed 461.549010992
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 664
# ** average fold accuracy 0.629518072289
# **time elapsed 556.023367882
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 671
# ** average fold accuracy 0.67958271237
# **time elapsed 649.525131941
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 681
# ** average fold accuracy 0.63436123348
# **time elapsed 744.772406816
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 662
# ** average fold accuracy 0.663141993958
# **time elapsed 838.972992897
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 632
# ** average fold accuracy 0.634493670886
# **time elapsed 934.079661846
# ------------------------------------end
# list of total accuracy for each fold [0.6676923076923077, 0.67149059334298122, 0.63323782234957016, 0.64506172839506171, 0.64779874213836475, 0.62951807228915657, 0.67958271236959766, 0.63436123348017626, 0.6631419939577039, 0.634493670886076]
# 10 -fold total average 0.65063788769
# time elapsed 934.081753969
#
# region: 2.0, gender: 2.0, intersect: 25000, 151647
# ------------------------------------start new k= 0 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 648
# ** average fold accuracy 0.600308641975
# **time elapsed 90.4795720577
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 614
# ** average fold accuracy 0.641693811075
# **time elapsed 179.858549833
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 658
# ** average fold accuracy 0.620060790274
# **time elapsed 270.301931858
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 617
# ** average fold accuracy 0.615883306321
# **time elapsed 359.455211878
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 650
# ** average fold accuracy 0.62
# **time elapsed 448.188500881
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 656
# ** average fold accuracy 0.631097560976
# **time elapsed 536.857880831
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 647
# ** average fold accuracy 0.619783616692
# **time elapsed 626.124222994
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 648
# ** average fold accuracy 0.617283950617
# **time elapsed 717.045860052
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 599
# ** average fold accuracy 0.602671118531
# **time elapsed 806.389857054
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 668
# ** average fold accuracy 0.631736526946
# **time elapsed 895.911426067
# ------------------------------------end
# list of total accuracy for each fold [0.60030864197530864, 0.64169381107491852, 0.62006079027355621, 0.6158833063209076, 0.62, 0.63109756097560976, 0.61978361669242654, 0.61728395061728392, 0.60267111853088484, 0.63173652694610782]
# 10 -fold total average 0.620051932341
# time elapsed 895.917597055
#
# region: 2.0, gender: 0.0, intersect: 25000, 151647
# ------------------------------------start new k= 0 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 622
# ** average fold accuracy 0.639871382637
# **time elapsed 89.6829030514
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 643
# ** average fold accuracy 0.673405909798
# **time elapsed 178.688645124
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 691
# ** average fold accuracy 0.661360347323
# **time elapsed 268.49232316
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 677
# ** average fold accuracy 0.663220088626
# **time elapsed 357.205168009
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 655
# ** average fold accuracy 0.665648854962
# **time elapsed 446.704349995
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 644
# ** average fold accuracy 0.645962732919
# **time elapsed 535.154585123
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 653
# ** average fold accuracy 0.641653905054
# **time elapsed 623.850482941
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 605
# ** average fold accuracy 0.646280991736
# **time elapsed 715.289929152
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 651
# ** average fold accuracy 0.642089093702
# **time elapsed 803.977329016
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 22500 ,validation set= 2500
# ** number of elements in calculation 649
# ** average fold accuracy 0.591679506934
# **time elapsed 893.233683109
# ------------------------------------end
# list of total accuracy for each fold [0.63987138263665599, 0.67340590979782267, 0.66136034732272064, 0.66322008862629245, 0.66564885496183201, 0.64596273291925466, 0.64165390505359876, 0.64628099173553721, 0.64208909370199696, 0.59167950693374427]
# 10 -fold total average 0.647117281369
# time elapsed 893.236624956
# region: 3.0, gender: 1.0, intersect: 6837, 151647
# ------------------------------------start new k= 0 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 199
# ** average fold accuracy 0.572864321608
# **time elapsed 7.12711715698
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 192
# ** average fold accuracy 0.526041666667
# **time elapsed 14.2127420902
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 189
# ** average fold accuracy 0.481481481481
# **time elapsed 21.2192280293
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 180
# ** average fold accuracy 0.6
# **time elapsed 28.335078001
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 209
# ** average fold accuracy 0.55023923445
# **time elapsed 35.3692059517
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 197
# ** average fold accuracy 0.53807106599
# **time elapsed 42.5380649567
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 6153 ,validation set= 684
# ** number of elements in calculation 165
# ** average fold accuracy 0.539393939394
# **time elapsed 49.5822629929
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 6154 ,validation set= 683
# ** number of elements in calculation 189
# ** average fold accuracy 0.57671957672
# **time elapsed 56.6295390129
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 6154 ,validation set= 683
# ** number of elements in calculation 170
# ** average fold accuracy 0.5
# **time elapsed 63.6891419888
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 6154 ,validation set= 683
# ** number of elements in calculation 179
# ** average fold accuracy 0.491620111732
# **time elapsed 70.9950311184
# ------------------------------------end
# list of total accuracy for each fold [0.57286432160804024, 0.52604166666666663, 0.48148148148148145, 0.59999999999999998, 0.55023923444976075, 0.53807106598984766, 0.53939393939393943, 0.57671957671957674, 0.5, 0.49162011173184356]
# 10 -fold total average 0.537643139804
# time elapsed 70.9957771301
#
# region: 3.0, gender: 2.0, intersect: 5121, 151647
# ------------------------------------start new k= 0 ,train set= 4608 ,validation set= 513
# ** number of elements in calculation 133
# ** average fold accuracy 0.541353383459
# **time elapsed 4.51813006401
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 132
# ** average fold accuracy 0.522727272727
# **time elapsed 8.91215395927
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 153
# ** average fold accuracy 0.542483660131
# **time elapsed 13.3397591114
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 130
# ** average fold accuracy 0.453846153846
# **time elapsed 17.8329081535
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 133
# ** average fold accuracy 0.593984962406
# **time elapsed 22.3486471176
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 141
# ** average fold accuracy 0.524822695035
# **time elapsed 26.8508961201
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 138
# ** average fold accuracy 0.492753623188
# **time elapsed 31.3702890873
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 129
# ** average fold accuracy 0.488372093023
# **time elapsed 35.887196064
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 157
# ** average fold accuracy 0.535031847134
# **time elapsed 40.4118800163
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 4609 ,validation set= 512
# ** number of elements in calculation 146
# ** average fold accuracy 0.452054794521
# **time elapsed 44.9267950058
# ------------------------------------end
# list of total accuracy for each fold [0.54135338345864659, 0.52272727272727271, 0.54248366013071891, 0.45384615384615384, 0.59398496240601506, 0.52482269503546097, 0.49275362318840582, 0.48837209302325579, 0.53503184713375795, 0.45205479452054792]
# 10 -fold total average 0.514743048547
# time elapsed 44.9278731346
#
# region: 3.0, gender: 0.0, intersect: 13182, 151647
# ------------------------------------start new k= 0 ,train set= 11863 ,validation set= 1319
# ** number of elements in calculation 386
# ** average fold accuracy 0.608808290155
# **time elapsed 25.7289361954
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 11863 ,validation set= 1319
# ** number of elements in calculation 357
# ** average fold accuracy 0.540616246499
# **time elapsed 51.3072509766
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 356
# ** average fold accuracy 0.544943820225
# **time elapsed 77.2547440529
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 372
# ** average fold accuracy 0.575268817204
# **time elapsed 102.586982965
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 380
# ** average fold accuracy 0.518421052632
# **time elapsed 127.918246031
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 379
# ** average fold accuracy 0.564643799472
# **time elapsed 153.092535973
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 340
# ** average fold accuracy 0.608823529412
# **time elapsed 178.169864178
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 344
# ** average fold accuracy 0.578488372093
# **time elapsed 203.310559988
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 350
# ** average fold accuracy 0.602857142857
# **time elapsed 228.401643991
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 11864 ,validation set= 1318
# ** number of elements in calculation 350
# ** average fold accuracy 0.534285714286
# **time elapsed 254.041543007
# ------------------------------------end
# list of total accuracy for each fold [0.60880829015544047, 0.54061624649859941, 0.5449438202247191, 0.57526881720430112, 0.51842105263157889, 0.56464379947229548, 0.60882352941176465, 0.57848837209302328, 0.60285714285714287, 0.53428571428571425]
# 10 -fold total average 0.567715678483
# time elapsed 254.042528152
# region: 4.0, gender: 1.0, intersect: 1952, 151647
# ------------------------------------start new k= 0 ,train set= 1756 ,validation set= 196
# ** number of elements in calculation 57
# ** average fold accuracy 0.40350877193
# **time elapsed 0.928881883621
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 1756 ,validation set= 196
# ** number of elements in calculation 61
# ** average fold accuracy 0.393442622951
# **time elapsed 1.86623597145
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 67
# ** average fold accuracy 0.373134328358
# **time elapsed 2.81937503815
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 55
# ** average fold accuracy 0.509090909091
# **time elapsed 3.73983693123
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 58
# ** average fold accuracy 0.448275862069
# **time elapsed 4.67305898666
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 56
# ** average fold accuracy 0.410714285714
# **time elapsed 5.58981990814
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 46
# ** average fold accuracy 0.45652173913
# **time elapsed 6.51380395889
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 43
# ** average fold accuracy 0.325581395349
# **time elapsed 7.44914102554
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 60
# ** average fold accuracy 0.5
# **time elapsed 8.36562800407
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 1757 ,validation set= 195
# ** number of elements in calculation 48
# ** average fold accuracy 0.354166666667
# **time elapsed 9.28464603424
# ------------------------------------end
# list of total accuracy for each fold [0.40350877192982454, 0.39344262295081966, 0.37313432835820898, 0.50909090909090904, 0.44827586206896552, 0.4107142857142857, 0.45652173913043476, 0.32558139534883723, 0.5, 0.35416666666666669]
# 10 -fold total average 0.417443658126
# time elapsed 9.28557991982
#
# region: 4.0, gender: 2.0, intersect: 1487, 151647
# ------------------------------------start new k= 0 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 45
# ** average fold accuracy 0.355555555556
# **time elapsed 0.451879024506
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 40
# ** average fold accuracy 0.225
# **time elapsed 0.900727987289
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 39
# ** average fold accuracy 0.384615384615
# **time elapsed 1.35590410233
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 36
# ** average fold accuracy 0.333333333333
# **time elapsed 1.79957509041
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 30
# ** average fold accuracy 0.5
# **time elapsed 2.24465894699
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 33
# ** average fold accuracy 0.484848484848
# **time elapsed 2.70123791695
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 1338 ,validation set= 149
# ** number of elements in calculation 45
# ** average fold accuracy 0.511111111111
# **time elapsed 3.14903903008
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 1339 ,validation set= 148
# ** number of elements in calculation 43
# ** average fold accuracy 0.46511627907
# **time elapsed 3.59685707092
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 1339 ,validation set= 148
# ** number of elements in calculation 36
# ** average fold accuracy 0.472222222222
# **time elapsed 4.04625296593
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 1339 ,validation set= 148
# ** number of elements in calculation 41
# ** average fold accuracy 0.536585365854
# **time elapsed 4.49601197243
# ------------------------------------end
# list of total accuracy for each fold [0.35555555555555557, 0.22500000000000001, 0.38461538461538464, 0.33333333333333331, 0.5, 0.48484848484848486, 0.51111111111111107, 0.46511627906976744, 0.47222222222222221, 0.53658536585365857]
# 10 -fold total average 0.426838773661
# time elapsed 4.49687790871
#
# region: 4.0, gender: 0.0, intersect: 3779, 151647
# ------------------------------------start new k= 0 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 107
# ** average fold accuracy 0.495327102804
# **time elapsed 2.55996203423
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 111
# ** average fold accuracy 0.459459459459
# **time elapsed 5.04483795166
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 119
# ** average fold accuracy 0.521008403361
# **time elapsed 7.50647211075
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 92
# ** average fold accuracy 0.45652173913
# **time elapsed 9.91178607941
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 95
# ** average fold accuracy 0.494736842105
# **time elapsed 12.2484679222
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 97
# ** average fold accuracy 0.484536082474
# **time elapsed 14.472244978
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 106
# ** average fold accuracy 0.481132075472
# **time elapsed 16.9233601093
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 101
# ** average fold accuracy 0.445544554455
# **time elapsed 19.3435909748
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 3401 ,validation set= 378
# ** number of elements in calculation 111
# ** average fold accuracy 0.513513513514
# **time elapsed 21.7823441029
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 3402 ,validation set= 377
# ** number of elements in calculation 100
# ** average fold accuracy 0.54
# **time elapsed 24.1747560501
# ------------------------------------end
# list of total accuracy for each fold [0.49532710280373832, 0.45945945945945948, 0.52100840336134457, 0.45652173913043476, 0.49473684210526314, 0.4845360824742268, 0.48113207547169812, 0.44554455445544555, 0.51351351351351349, 0.54000000000000004]
# 10 -fold total average 0.489177977278
# time elapsed 24.1755621433
#
# region: 5.0, gender: 1.0, intersect: 11463, 151647
# ------------------------------------start new k= 0 ,train set= 10316 ,validation set= 1147
# ** number of elements in calculation 310
# ** average fold accuracy 0.596774193548
# **time elapsed 19.439027071
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 10316 ,validation set= 1147
# ** number of elements in calculation 355
# ** average fold accuracy 0.549295774648
# **time elapsed 38.7424190044
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 10316 ,validation set= 1147
# ** number of elements in calculation 350
# ** average fold accuracy 0.534285714286
# **time elapsed 57.8108530045
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 310
# ** average fold accuracy 0.61935483871
# **time elapsed 76.8960249424
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 350
# ** average fold accuracy 0.548571428571
# **time elapsed 96.2089040279
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 311
# ** average fold accuracy 0.585209003215
# **time elapsed 115.318392992
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 346
# ** average fold accuracy 0.537572254335
# **time elapsed 134.437572956
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 321
# ** average fold accuracy 0.545171339564
# **time elapsed 153.696542025
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 324
# ** average fold accuracy 0.570987654321
# **time elapsed 172.848284006
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 10317 ,validation set= 1146
# ** number of elements in calculation 284
# ** average fold accuracy 0.552816901408
# **time elapsed 191.850353956
# ------------------------------------end
# list of total accuracy for each fold [0.59677419354838712, 0.54929577464788737, 0.53428571428571425, 0.61935483870967745, 0.5485714285714286, 0.58520900321543412, 0.53757225433526012, 0.54517133956386288, 0.57098765432098764, 0.55281690140845074]
# 10 -fold total average 0.564003910261
# time elapsed 191.851320028
#
# region: 5.0, gender: 2.0, intersect: 8390, 151647
# ------------------------------------start new k= 0 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 211
# ** average fold accuracy 0.488151658768
# **time elapsed 11.491918087
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 218
# ** average fold accuracy 0.545871559633
# **time elapsed 22.8886830807
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 240
# ** average fold accuracy 0.516666666667
# **time elapsed 34.1951260567
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 248
# ** average fold accuracy 0.504032258065
# **time elapsed 45.7139639854
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 260
# ** average fold accuracy 0.573076923077
# **time elapsed 57.1569731236
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 243
# ** average fold accuracy 0.522633744856
# **time elapsed 68.2631011009
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 230
# ** average fold accuracy 0.513043478261
# **time elapsed 79.7230091095
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 223
# ** average fold accuracy 0.560538116592
# **time elapsed 91.0403602123
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 204
# ** average fold accuracy 0.509803921569
# **time elapsed 102.376792192
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 7551 ,validation set= 839
# ** number of elements in calculation 237
# ** average fold accuracy 0.540084388186
# **time elapsed 113.787787199
# ------------------------------------end
# list of total accuracy for each fold [0.4881516587677725, 0.54587155963302747, 0.51666666666666672, 0.50403225806451613, 0.57307692307692304, 0.52263374485596703, 0.5130434782608696, 0.5605381165919282, 0.50980392156862742, 0.54008438818565396]
# 10 -fold total average 0.527390271567
# time elapsed 113.788705111
#
# region: 5.0, gender: 0.0, intersect: 21856, 151647
# ------------------------------------start new k= 0 ,train set= 19670 ,validation set= 2186
# ** number of elements in calculation 590
# ** average fold accuracy 0.577966101695
# **time elapsed 68.1817669868
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 19670 ,validation set= 2186
# ** number of elements in calculation 628
# ** average fold accuracy 0.59872611465
# **time elapsed 142.059710979
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 19670 ,validation set= 2186
# ** number of elements in calculation 598
# ** average fold accuracy 0.580267558528
# **time elapsed 217.317604065
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 19670 ,validation set= 2186
# ** number of elements in calculation 581
# ** average fold accuracy 0.5834767642
# **time elapsed 290.727731943
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 19670 ,validation set= 2186
# ** number of elements in calculation 616
# ** average fold accuracy 0.571428571429
# **time elapsed 364.793869019
# ...
# ** average fold accuracy 0.456140350877
# **time elapsed 0.961344003677
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 1783 ,validation set= 199
# ** number of elements in calculation 49
# ** average fold accuracy 0.387755102041
# **time elapsed 1.92147397995
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 57
# ** average fold accuracy 0.491228070175
# **time elapsed 2.88852190971
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 58
# ** average fold accuracy 0.327586206897
# **time elapsed 3.83019900322
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 57
# ** average fold accuracy 0.438596491228
# **time elapsed 4.77433586121
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 46
# ** average fold accuracy 0.478260869565
# **time elapsed 5.70493888855
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 63
# ** average fold accuracy 0.444444444444
# **time elapsed 6.66670298576
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 59
# ** average fold accuracy 0.35593220339
# **time elapsed 7.61158204079
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 54
# ** average fold accuracy 0.351851851852
# **time elapsed 8.55368995667
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 1784 ,validation set= 198
# ** number of elements in calculation 46
# ** average fold accuracy 0.45652173913
# **time elapsed 9.50267195702
# ------------------------------------end
# list of total accuracy for each fold [0.45614035087719296, 0.38775510204081631, 0.49122807017543857, 0.32758620689655171, 0.43859649122807015, 0.47826086956521741, 0.44444444444444442, 0.3559322033898305, 0.35185185185185186, 0.45652173913043476]
# 10 -fold total average 0.41883173296
# time elapsed 9.50383996964
#
# region: 8.0, gender: 0.0, intersect: 5181, 151647
# ------------------------------------start new k= 0 ,train set= 4662 ,validation set= 519
# ** number of elements in calculation 142
# ** average fold accuracy 0.56338028169
# **time elapsed 4.33896183968
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 148
# ** average fold accuracy 0.506756756757
# **time elapsed 8.72881293297
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 150
# ** average fold accuracy 0.486666666667
# **time elapsed 13.058360815
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 127
# ** average fold accuracy 0.55905511811
# **time elapsed 17.3592119217
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 148
# ** average fold accuracy 0.533783783784
# **time elapsed 21.6500608921
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 144
# ** average fold accuracy 0.541666666667
# **time elapsed 25.7048959732
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 152
# ** average fold accuracy 0.532894736842
# **time elapsed 29.9706609249
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 133
# ** average fold accuracy 0.548872180451
# **time elapsed 34.2386658192
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 146
# ** average fold accuracy 0.534246575342
# **time elapsed 38.5586659908
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 4663 ,validation set= 518
# ** number of elements in calculation 129
# ** average fold accuracy 0.53488372093
# **time elapsed 42.7874748707
# ------------------------------------end
# list of total accuracy for each fold [0.56338028169014087, 0.5067567567567568, 0.48666666666666669, 0.55905511811023623, 0.53378378378378377, 0.54166666666666663, 0.53289473684210531, 0.54887218045112784, 0.53424657534246578, 0.53488372093023251]
# 10 -fold total average 0.534220648724
# time elapsed 42.7884948254
#
# region: 9.0, gender: 1.0, intersect: 9336, 151647
# ------------------------------------start new k= 0 ,train set= 8402 ,validation set= 934
# ** number of elements in calculation 241
# ** average fold accuracy 0.55601659751
# **time elapsed 12.8578579426
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 8402 ,validation set= 934
# ** number of elements in calculation 262
# ** average fold accuracy 0.511450381679
# **time elapsed 25.7020568848
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 8402 ,validation set= 934
# ** number of elements in calculation 238
# ** average fold accuracy 0.474789915966
# **time elapsed 38.5055370331
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 8402 ,validation set= 934
# ** number of elements in calculation 251
# ** average fold accuracy 0.581673306773
# **time elapsed 51.3984839916
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 8402 ,validation set= 934
# ** number of elements in calculation 246
# ** average fold accuracy 0.520325203252
# **time elapsed 64.2871940136
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 8402 ,validation set= 934
# ** number of elements in calculation 274
# ** average fold accuracy 0.569343065693
# **time elapsed 77.3193838596
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 8403 ,validation set= 933
# ** number of elements in calculation 251
# ** average fold accuracy 0.545816733068
# **time elapsed 90.4289729595
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 8403 ,validation set= 933
# ** number of elements in calculation 241
# ** average fold accuracy 0.589211618257
# **time elapsed 103.345237017
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 8403 ,validation set= 933
# ** number of elements in calculation 247
# ** average fold accuracy 0.534412955466
# **time elapsed 116.268375874
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 8403 ,validation set= 933
# ** number of elements in calculation 238
# ** average fold accuracy 0.588235294118
# **time elapsed 128.92427206
# ------------------------------------end
# list of total accuracy for each fold [0.55601659751037347, 0.51145038167938928, 0.47478991596638653, 0.58167330677290841, 0.52032520325203258, 0.56934306569343063, 0.54581673306772904, 0.58921161825726143, 0.53441295546558709, 0.58823529411764708]
# 10 -fold total average 0.547127507178
# time elapsed 128.924968958
#
# region: 9.0, gender: 2.0, intersect: 7111, 151647
# ------------------------------------start new k= 0 ,train set= 6399 ,validation set= 712
# ** number of elements in calculation 194
# ** average fold accuracy 0.494845360825
# **time elapsed 8.22655892372
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 175
# ** average fold accuracy 0.491428571429
# **time elapsed 16.3487889767
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 179
# ** average fold accuracy 0.530726256983
# **time elapsed 24.4665539265
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 192
# ** average fold accuracy 0.505208333333
# **time elapsed 32.6193618774
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 213
# ** average fold accuracy 0.492957746479
# **time elapsed 40.6836118698
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 212
# ** average fold accuracy 0.537735849057
# **time elapsed 48.9958648682
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 198
# ** average fold accuracy 0.484848484848
# **time elapsed 57.0950870514
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 191
# ** average fold accuracy 0.450261780105
# **time elapsed 65.2134799957
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 209
# ** average fold accuracy 0.511961722488
# **time elapsed 73.4648740292
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 6400 ,validation set= 711
# ** number of elements in calculation 202
# ** average fold accuracy 0.524752475248
# **time elapsed 81.7541339397
# ------------------------------------end
# list of total accuracy for each fold [0.49484536082474229, 0.49142857142857144, 0.53072625698324027, 0.50520833333333337, 0.49295774647887325, 0.53773584905660377, 0.48484848484848486, 0.45026178010471202, 0.51196172248803828, 0.52475247524752477]
# 10 -fold total average 0.502472658079
# time elapsed 81.7553060055
#
# region: 9.0, gender: 0.0, intersect: 18033, 151647
# ------------------------------------start new k= 0 ,train set= 16229 ,validation set= 1804
# ** number of elements in calculation 458
# ** average fold accuracy 0.561135371179
# **time elapsed 47.3461081982
# ------------------------------------end
# ------------------------------------start new k= 1 ,train set= 16229 ,validation set= 1804
# ** number of elements in calculation 493
# ** average fold accuracy 0.521298174442
# **time elapsed 94.1495790482
# ------------------------------------end
# ------------------------------------start new k= 2 ,train set= 16229 ,validation set= 1804
# ** number of elements in calculation 470
# ** average fold accuracy 0.534042553191
# **time elapsed 141.045911074
# ------------------------------------end
# ------------------------------------start new k= 3 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 508
# ** average fold accuracy 0.55905511811
# **time elapsed 188.143850088
# ------------------------------------end
# ------------------------------------start new k= 4 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 487
# ** average fold accuracy 0.570841889117
# **time elapsed 235.029736996
# ------------------------------------end
# ------------------------------------start new k= 5 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 505
# ** average fold accuracy 0.570297029703
# **time elapsed 282.026754141
# ------------------------------------end
# ------------------------------------start new k= 6 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 502
# ** average fold accuracy 0.529880478088
# **time elapsed 328.954020977
# ------------------------------------end
# ------------------------------------start new k= 7 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 491
# ** average fold accuracy 0.564154786151
# **time elapsed 375.49813509
# ------------------------------------end
# ------------------------------------start new k= 8 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 497
# ** average fold accuracy 0.551307847082
# **time elapsed 422.142726183
# ------------------------------------end
# ------------------------------------start new k= 9 ,train set= 16230 ,validation set= 1803
# ** number of elements in calculation 480
# ** average fold accuracy 0.59375
# **time elapsed 469.756281137
# ------------------------------------end
# list of total accuracy for each fold [0.56113537117903933, 0.52129817444219062, 0.53404255319148941, 0.55905511811023623, 0.57084188911704314, 0.57029702970297025, 0.52988047808764938, 0.56415478615071279, 0.55130784708249492, 0.59375]
# 10 -fold total average 0.555576324706
# time elapsed 469.758023024
# too little data with region 10.0 and gender 1.0 found
# too little data with region 10.0 and gender 2.0 found
# too little data with region 10.0 and gender 0.0 found
# too little data with region 11.0 and gender 1.0 found
# too little data with region 11.0 and gender 2.0 found
# too little data with region 11.0 and gender 0.0 found
# too little data with region 12.0 and gender 1.0 found
# too little data with region 12.0 and gender 2.0 found
# too little data with region 12.0 and gender 0.0 found
# too little data with region 13.0 and gender 1.0 found
# too little data with region 13.0 and gender 2.0 found
# too little data with region 13.0 and gender 0.0 found
# region: 14.0 not found
# too little data with region 15.0 and gender 1.0 found
# too little data with region 15.0 and gender 2.0 found
# too little data with region 15.0 and gender 0.0 found
# region: 16.0 not found
# region: 17.0 not found
# too little data with region 18.0 and gender 1.0 found
# too little data with region 18.0 and gender 2.0 found
# too little data with region 18.0 and gender 0.0 found
# region: 19.0 not found
# too little data with region 20.0 and gender 1.0 found
# too little data with region 20.0 and gender 2.0 found
# too little data with region 20.0 and gender 0.0 found
# too little data with region 21.0 and gender 1.0 found
# too little data with region 21.0 and gender 2.0 found
# too little data with region 21.0 and gender 0.0 found
# too little data with region 22.0 and gender 1.0 found
# too little data with region 22.0 and gender 2.0 found
# too little data with region 22.0 and gender 0.0 found
# region: 23.0 not found
# region: 24.0 not found
# region: 25.0 not found
# region: 26.0 not found
# region: 27.0 not found
# too little data with region 28.0 and gender 1.0 found
# too little data with region 28.0 and gender 2.0 found
# too little data with region 28.0 and gender 0.0 found
# region: 29.0 not found
# too little data with region 30.0 and gender 1.0 found
# too little data with region 30.0 and gender 2.0 found
# too little data with region 30.0 and gender 0.0 found
# region: 31.0 not found
# region: 32.0 not found
# region: 33.0 not found
# region: 34.0 not found
# too little data with region 35.0 and gender 1.0 found
# too little data with region 35.0 and gender 2.0 found
# too little data with region 35.0 and gender 0.0 found
# region: 36.0 not found
# region: 37.0 not found
# region: 38.0 not found
# region: 39.0 not found
# region: 40.0 not found
# region: 41.0 not found

# %%
demo_results
# Out:
# [(0.0, 1.0, 25000, 0.63021129129005082),
#  (0.0, 2.0, 25000, 0.58928032527908458),
#  (0.0, 0.0, 25000, 0.61261214188248769),
#  (1.0, 1.0, 7924, 0.58622166842109924),
#  (1.0, 2.0, 6579, 0.53207443609961458),
#  (1.0, 0.0, 15758, 0.5876985518511354),
#  (2.0, 1.0, 25000, 0.65063788769009956),
#  (2.0, 2.0, 25000, 0.62005193234070033),
#  (2.0, 0.0, 25000, 0.64711728136894542),
#  (3.0, 1.0, 6837, 0.53764313980411571),
#  (3.0, 2.0, 5121, 0.51474304854702357),
#  (3.0, 0.0, 13182, 0.56771567848345794),
#  (4.0, 1.0, 1952, 0.41744365812589523),
#  (4.0, 2.0, 1487, 0.42683877366095169),
#  (4.0, 0.0, 3779, 0.48917797727751244),
#  (5.0, 1.0, 11463, 0.56400391026070895),
#  (5.0, 2.0, 8390, 0.5273902715671952),
#  (5.0, 0.0, 21856, 0.58439760127801332),
#  (6.0, 1.0, 1184, 0.38824033901404675),
#  (6.0, 0.0, 2203, 0.4397824719079434),
#  (7.0, 1.0, 3200, 0.48116420435288776),
#  (7.0, 2.0, 2282, 0.42731026098927349),
#  (7.0, 0.0, 6115, 0.5236092406630658),
#  (8.0, 1.0, 2796, 0.4887248725036839),
#  (8.0, 2.0, 1982, 0.41883173295998483),
#  (8.0, 0.0, 5181, 0.5342206487240182),
#  (9.0, 1.0, 9336, 0.54712750717827452),
#  (9.0, 2.0, 7111, 0.50247265807941255),
#  (9.0, 0.0, 18033, 0.55557632470638263)]

# %%
np.save('demo_results_big_1k-25k.npy',[(maximum_rows,minimum_rows,seed,datetime.now().strftime("%Y-%m-%d_%H:%M:%S"))]+demo_results)

# %%
demo_results_copy = np.load('demo_results_big_1k-25k.npy')
demo_results_copy
# Out:
# array([['25000', '1000', '0', '2017-11-30_03:01:44'],
#        ['0.0', '1.0', '25000', '0.63021129129'],
#        ['0.0', '2.0', '25000', '0.589280325279'],
#        ['0.0', '0.0', '25000', '0.612612141882'],
#        ['1.0', '1.0', '7924', '0.586221668421'],
#        ['1.0', '2.0', '6579', '0.5320744361'],
#        ['1.0', '0.0', '15758', '0.587698551851'],
#        ['2.0', '1.0', '25000', '0.65063788769'],
#        ['2.0', '2.0', '25000', '0.620051932341'],
#        ['2.0', '0.0', '25000', '0.647117281369'],
#        ['3.0', '1.0', '6837', '0.537643139804'],
#        ['3.0', '2.0', '5121', '0.514743048547'],
#        ['3.0', '0.0', '13182', '0.567715678483'],
#        ['4.0', '1.0', '1952', '0.417443658126'],
#        ['4.0', '2.0', '1487', '0.426838773661'],
#        ['4.0', '0.0', '3779', '0.489177977278'],
#        ['5.0', '1.0', '11463', '0.564003910261'],
#        ['5.0', '2.0', '8390', '0.527390271567'],
#        ['5.0', '0.0', '21856', '0.584397601278'],
#        ['6.0', '1.0', '1184', '0.388240339014'],
#        ['6.0', '0.0', '2203', '0.439782471908'],
#        ['7.0', '1.0', '3200', '0.481164204353'],
#        ['7.0', '2.0', '2282', '0.427310260989'],
#        ['7.0', '0.0', '6115', '0.523609240663'],
#        ['8.0', '1.0', '2796', '0.488724872504'],
#        ['8.0', '2.0', '1982', '0.41883173296'],
#        ['8.0', '0.0', '5181', '0.534220648724'],
#        ['9.0', '1.0', '9336', '0.547127507178'],
#        ['9.0', '2.0', '7111', '0.502472658079'],
#        ['9.0', '0.0', '18033', '0.555576324706']],
#       dtype='|S21')

# %%
drs = pd.DataFrame(demo_results_copy[1:],columns=['region','gender','size','accuracy'])

# %%
drs
# Out:
#    region gender   size        accuracy
# 0     0.0    1.0  25000   0.63021129129
# 1     0.0    2.0  25000  0.589280325279
# 2     0.0    0.0  25000  0.612612141882
# 3     1.0    1.0   7924  0.586221668421
# 4     1.0    2.0   6579    0.5320744361
# 5     1.0    0.0  15758  0.587698551851
# 6     2.0    1.0  25000   0.65063788769
# 7     2.0    2.0  25000  0.620051932341
# 8     2.0    0.0  25000  0.647117281369
# 9     3.0    1.0   6837  0.537643139804
# 10    3.0    2.0   5121  0.514743048547
# 11    3.0    0.0  13182  0.567715678483
# 12    4.0    1.0   1952  0.417443658126
# 13    4.0    2.0   1487  0.426838773661
# 14    4.0    0.0   3779  0.489177977278
# 15    5.0    1.0  11463  0.564003910261
# 16    5.0    2.0   8390  0.527390271567
# 17    5.0    0.0  21856  0.584397601278
# 18    6.0    1.0   1184  0.388240339014
# 19    6.0    0.0   2203  0.439782471908
# 20    7.0    1.0   3200  0.481164204353
# 21    7.0    2.0   2282  0.427310260989
# 22    7.0    0.0   6115  0.523609240663
# 23    8.0    1.0   2796  0.488724872504
# 24    8.0    2.0   1982   0.41883173296
# 25    8.0    0.0   5181  0.534220648724
# 26    9.0    1.0   9336  0.547127507178
# 27    9.0    2.0   7111  0.502472658079
# 28    9.0    0.0  18033  0.555576324706
